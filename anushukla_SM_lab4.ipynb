# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sea
plt.style.use('default')

# %%
price=[400,600,900,1000,500,500]
year=[2012,2022,2022,2019,2018,2018]
plt.plot(price,year,'red')
plt.grid()

# %%
stu= pd.read_csv('/content/students.csv')
stu
plt.plot(stu='student_id')
# Out:
# []

# %%
batsman= pd.read_csv('/content/sharma-kohli.csv')
batsman
plt.plot(batsman['index'],batsman['V Kohli'])

# %%
plt.plot(batsman['index'],batsman['V Kohli'],color='red',linestyle='solid',linewidth=3,marker='D',markersize=10)
plt.plot(batsman['index'],batsman['RG Sharma'],color='blue',linestyle='dashdot',linewidth=2,marker='o',markersize=10)

plt.title('Rohit Sharma Vs Virat Kohli Career Comparison')
plt.xlabel('season')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')
